# %%
my_list=[4,44,444,['sara','vala'],23.4]

# %%
print(my_list)
# Out:
# [4, 44, 444, ['sara', 'vala'], 23.4]

# %%
print(my_list[3])
# Out:
# ['sara', 'vala']

# %%
my_list.insert(2,'hello')

# %%
print(my_list)
# Out:
# ['hello', 4, 'hello', 44, 444, ['sara', 'vala'], 23.4]
